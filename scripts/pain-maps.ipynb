# %%
from pain2map import PainMode
import os

# %%
BASE_PATH = os.path.join("D:\\", "Workspaces", "vscode-workspace", "ai_x_medicine", "data")
WORLD_PATH = os.path.join(BASE_PATH, "countries_map.zip")
OUTPUT_PATH = os.path.join(BASE_PATH, "out", "maps_new")

# %%
def gen_map(mode: PainMode):
    mode.generate_map(BASE_PATH, WORLD_PATH, os.path.join(OUTPUT_PATH, f"{mode.abbreviation}.png"))

# %%
gen_map(PainMode.Physical)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 gen_map(PainMode.Physical)
#
# Cell In[7], line 2, in gen_map(mode)
#       1 def gen_map(mode: PainMode):
# ----> 2     mode.generate_map(BASE_PATH, WORLD_PATH, os.path.join(OUTPUT_PATH, f"{mode.abbreviation}.png"))
#
# File d:\Workspaces\vscode-workspace\ai_x_medicine\scripts\pain2map\pain_mode.py:103, in PainMode.generate_map(self, base_path, world_path, output_path, args_value_col, args_code_col)
#     100 dataframe[args_code_col] = dataframe[args_code_col].astype(str).str.upper().str.strip()
#     102 # Load world geometries
# --> 103 world = self._load_world(world_path)
#     105 # Merge
#     106 merged = world.merge(dataframe[[args_code_col, args_value_col]], left_on=CODE_COLUMN, right_on=args_code_col, how="left")
#
# File d:\Workspaces\vscode-workspace\ai_x_medicine\scripts\pain2map\pain_mode.py:80, in PainMode._load_world(self, file_path, verbose)
#      78 def _load_world(self, file_path: str, verbose: bool = False):
#      79     # Use Natural Earth low-res that ships with GeoPandas
# ---> 80     world = gpd.read_file(file_path)
#      81     if verbose:
#      82         print(world)
#
# File d:\Programs\anaconda3\envs\PPPMap\lib\site-packages\geopandas\io\file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     278     else:
#     279         path_or_bytes = filename
# --> 281     return _read_file_fiona(
#     282         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     283     )
#     285 else:
#     286     raise ValueError(f"unknown engine '{engine}'")
#
# File d:\Programs\anaconda3\envs\PPPMap\lib\site-packages\geopandas\io\file.py:299, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     293     raise NotImplementedError("where requires fiona 1.9+")
#     295 if not from_bytes:
#     296     # Opening a file via URL or file-like-object above automatically detects a
#     297     # zipped file. In order to match that behavior, attempt to add a zip scheme
#     298     # if missing.
# --> 299     if _is_zip(str(path_or_bytes)):
#     300         parsed = fiona.parse_path(str(path_or_bytes))
#     301         if isinstance(parsed, fiona.path.ParsedPath):
#     302             # If fiona is able to parse the path, we can safely look at the scheme
#     303             # and update it to have a zip scheme if necessary.
#
# File d:\Programs\anaconda3\envs\PPPMap\lib\site-packages\geopandas\io\file.py:166, in _is_zip(path)
#     164 def _is_zip(path):
#     165     """Check if a given path is a zipfile"""
# --> 166     parsed = fiona.path.ParsedPath.from_uri(path)
#     167     return (
#     168         parsed.archive.endswith(".zip")
#     169         if parsed.archive
#     170         else parsed.path.endswith(".zip")
#     171     )
#
# AttributeError: module 'fiona' has no attribute 'path'
