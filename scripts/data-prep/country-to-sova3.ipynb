# %%
import os
import pandas as pd
import geopandas as gpd

from typing import Tuple, Set

# %% [markdown]
# # Setup

# %%
BASE_PATH = os.path.join("D:\\", "Workspaces", "vscode-workspace", "ai_x_medicine", "data")
RES_GDP_PATH = os.path.join(BASE_PATH, "out", "res-gdp.csv")
RES_GINI_PATH = os.path.join(BASE_PATH, "out", "res-gini.csv")
#RES_FIRE_PATH = os.path.join(BASE_PATH, "env_fire-new.csv")
RES_PAIN_PATH = os.path.join(BASE_PATH, "out", "socioeconomic-pain.csv")

RES_GINI_SOV_PATH = os.path.join(BASE_PATH, "out", "res-gini-sov.csv")
#RES_FIRE_SOV_PATH = os.path.join(BASE_PATH, "env_fire-sov.csv")
RES_PAIN_SOV_PATH = os.path.join(BASE_PATH, "out", "socioeconomic-pain-sov.csv")

# %%
def load_world(verbose: bool = False):
    # Use Natural Earth low-res that ships with GeoPandas
    #world_path = gpd.datasets.get_path("naturalearth_lowres")
    world = gpd.read_file(os.path.join(BASE_PATH, "countries_map.zip"))#"https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip")
    #world = gpd.read_file("https://naciscdn.org/naturalearth/110m/physical/ne_110m_land.zip") #geodatasets.get_path("naturalearth_lowres"))
    if verbose: 
        print(world)
    # Fix some known ISO code quirks
    # Natural Earth uses "France" overseas territories as single polygon, ISO A3 is in 'iso_a3'
    world.loc[world["SOVEREIGNT"] == "France", "sov_a3"] = "FRA"
    world.loc[world["SOVEREIGNT"] == "Norway", "sov_a3"] = "NOR"
    world.loc[world["SOVEREIGNT"] == "Somaliland", "sov_a3"] = "SOL"  # non-ISO, avoid collision
    return world

# %%
def compute_sova3_subset(dataframe: pd.DataFrame, df_country_label: str = "Country", df_value_label: str = "value") -> Tuple[pd.DataFrame, Set]:
    # Find intersection of country/location names
    new_world = load_world()
    common_data = set(new_world["SOVEREIGNT"]).intersection(set(dataframe[df_country_label]))
    diff_data = set(new_world["SOVEREIGNT"]).difference(set(dataframe[df_country_label]))

    # Subset both DataFrames to only those in the intersection
    dataframe_sub = dataframe[dataframe["Country"].isin(common_data)].copy()

    result_data = []
    for _, row in dataframe_sub.iterrows():
        country = row[df_country_label]
        value = row[df_value_label]
        nw_row = new_world.loc[new_world["SOVEREIGNT"] == country]  # get the row corresponding to country
        sova3 = nw_row.iloc[0]["SOV_A3"]
        result_data.append({
            "sov_a3": sova3,
            "Country": country,
            "value": value
        })
    # add 0 values for mismatching data
    for country in diff_data:
        nw_row = new_world.loc[new_world["SOVEREIGNT"] == country]  # get the row corresponding to country
        sova3 = nw_row.iloc[0]["SOV_A3"]
        result_data.append({
            "sov_a3": sova3,
            "Country": country,
            "value": 0
        })
    #dataframe_sub.merge(new_world[["SOVEREIGNT", "SOV_A3"]], how="left")

    return pd.DataFrame(result_data), diff_data

# %% [markdown]
# # Data

# %%
# Adapt socio-economic pain data
df_pain = pd.read_csv(RES_PAIN_PATH, index_col=False)
df_pain_sub, _ = compute_sova3_subset(df_pain, "Country", "pain")
df_pain_sub.to_csv(RES_PAIN_SOV_PATH, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Adapt socio-economic pain data
# ----> 2 df_pain = pd.read_csv(RES_PAIN_PATH, index_col=False)
#       3 df_pain_sub, _ = compute_sova3_subset(df_pain, "Country", "pain")
#       4 df_pain_sub.to_csv(RES_PAIN_SOV_PATH, index=False)
#
# File d:\Programs\anaconda3\envs\PAIN\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File d:\Programs\anaconda3\envs\PAIN\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File d:\Programs\anaconda3\envs\PAIN\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File d:\Programs\anaconda3\envs\PAIN\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File d:\Programs\anaconda3\envs\PAIN\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Workspaces\\vscode-workspace\\ai_x_medicine\\data\\out\\socioeconomic-pain.csv'

# %%
df_gini = pd.read_csv(RES_GINI_PATH, index_col=False)
df_gini_sub, missing_countries = compute_sova3_subset(df_gini, "Country", "gini")
df_gini_sub.to_csv(RES_GINI_SOV_PATH, index=False)

print(f"The susbet includes {len(df_gini_sub['Country'])} out of {len(df_gini['Country'])}.")
print("The following countries are missing:")
for country in missing_countries:
    print(f"- {country}")
# Out:
# The susbet includes 171 out of 170.
# The following countries are missing:
# - North Korea
# - Libya
# - Brunei
# - Lebanon
# - Cuba
# - Eritrea
# - Saudi Arabia
# - Belize
# - Nepal
# - Antarctica
# - The Bahamas
# - United Republic of Tanzania
# - United States of America
# - Northern Cyprus
# - East Timor
# - Oman
# - eSwatini
# - Cambodia
# - Democratic Republic of the Congo
# - Afghanistan
# - Czechia
# - Equatorial Guinea
# - Western Sahara
# - New Zealand
# - Kosovo
# - Somaliland
# - Kuwait
# - Azerbaijan
# - Republic of Serbia

# %%
df_gdp = pd.read_csv(RES_GDP_PATH)
df_gdp_sub, missing_countries = compute_sova3_subset(df_gini, "Country")

print(f"The susbet includes {len(df_gdp_sub['Country'])} out of {len(df_gdp['Country'])}.")
print("The following countries are missing:")
for country in missing_countries:
    print(f"- {country}")
# Out:
# The susbet includes 142 out of 262.
# The following countries are missing:
# - Northern Cyprus
# - Oman
# - Cuba
# - Nepal
# - Kuwait
# - North Korea
# - Libya
# - Equatorial Guinea
# - The Bahamas
# - Western Sahara
# - Lebanon
# - United Republic of Tanzania
# - Cambodia
# - Republic of Serbia
# - United States of America
# - Somaliland
# - Kosovo
# - Azerbaijan
# - Belize
# - Saudi Arabia
# - Czechia
# - Eritrea
# - East Timor
# - Antarctica
# - eSwatini
# - New Zealand
# - Afghanistan
# - Brunei
# - Democratic Republic of the Congo

# %%
# prep FIRE
df_fire = pd.read_csv(RES_FIRE_PATH, index_col=False)
df_fire, missing_countries = compute_sova3_subset(df_fire, "Country", "fire_pain")
df_fire.to_csv(RES_FIRE_SOV_PATH, index=False)

print(f"The susbet includes {len(df_fire['Country'])} out of {len(df_fire['Country'])}.")
print("The following countries are missing:")
for country in missing_countries:
    print(f"- {country}")
# Out:
# The susbet includes 161 out of 161.
# The following countries are missing:
# - The Bahamas
# - Republic of Serbia
# - United Republic of Tanzania
# - Antarctica
# - Democratic Republic of the Congo
# - Somaliland
# - Ivory Coast
# - Republic of the Congo
# - United States of America
# - eSwatini

# %%
# prep EMOTIONAL
df_emo = pd.read_csv(os.path.join(BASE_PATH, "out", "emo-pain.csv"))
df_emo, missing_countries = compute_sova3_subset(df_emo, "Country", "value")
df_emo.to_csv(os.path.join(BASE_PATH, "out", "emo-sov.csv"), index=False)

print(f"The susbet includes {len(df_emo['Country'])} out of {len(df_emo['Country'])}.")
print("The following countries are missing:")
for country in missing_countries:
    print(f"- {country}")
# Out:
# The susbet includes 171 out of 171.
# The following countries are missing:
# - Republic of Serbia
# - Burkina Faso
# - Democratic Republic of the Congo
# - Dominican Republic
# - Solomon Islands
# - Laos
# - Guinea
# - Bosnia and Herzegovina
# - Vanuatu
# - Moldova
# - Guinea-Bissau
# - The Bahamas
# - El Salvador
# - Togo
# - Slovenia
# - eSwatini
# - Latvia
# - Romania
# - Northern Cyprus
# - Mauritania
# - United States of America
# - United Republic of Tanzania
# - Brunei
# - Czechia
# - Rwanda
# - Nicaragua
# - Kosovo
# - Central African Republic
# - Burundi
# - Niger
# - South Sudan
# - Suriname
# - Tajikistan
# - North Macedonia
# - Western Sahara
# - Botswana
# - Somaliland
# - Honduras
# - Equatorial Guinea
# - Lithuania
# - Republic of the Congo
# - East Timor
# - Slovakia

# %%
# prep PHYSICAL
df_physical = pd.read_csv(os.path.join(BASE_PATH, "physical-pain.csv"), index_col=False)
df_physical, missing_countries = compute_sova3_subset(df_physical, "Country", "val")
df_physical.to_csv(os.path.join(BASE_PATH, "out", "physical-sov.csv"), index=False)

print(f"The susbet includes {len(df_physical['Country'])} out of {len(df_physical['Country'])}.")
print("The following countries are missing:")
for country in missing_countries:
    print(f"- {country}")
# Out:
# The susbet includes 171 out of 171.
# The following countries are missing:
# - Republic of Serbia
# - Laos
# - Vietnam
# - Russia
# - Moldova
# - North Korea
# - The Bahamas
# - Bolivia
# - eSwatini
# - Syria
# - South Korea
# - Taiwan
# - Northern Cyprus
# - South Africa
# - Brunei
# - Brazil
# - Kosovo
# - Iran
# - Pakistan
# - Western Sahara
# - Venezuela
# - India
# - Antarctica
# - Somaliland
# - Ivory Coast
# - Republic of the Congo
# - East Timor

# %% [markdown]
# # Env

# %%
# prep ENVIRONMENT
df_env = pd.read_csv(os.path.join(BASE_PATH, "out", "hollistic_pains", "env-pain.csv"), index_col=False)
df_env, missing_countries = compute_sova3_subset(df_env, "Country", "value")
df_env.to_csv(os.path.join(BASE_PATH, "out", "sov_data", "env-sov.csv"), index=False)

print(f"The susbet includes {len(df_env['Country'])} out of {len(df_env['Country'])}.")
print("The following countries are missing:")
for country in missing_countries:
    print(f"- {country}")
# Out:
# The susbet includes 171 out of 171.
# The following countries are missing:

# %%
# prep individual environments
elements = ["water", "earth", "wood", "metal", "fire"]

for elem in elements:
    df_elem = pd.read_csv(os.path.join(BASE_PATH, "out", "env_pains", f"env-{elem}-pain.csv"), index_col=False)
    df_elem, _ = compute_sova3_subset(df_elem, "Country", "value")
    df_elem.to_csv(os.path.join(BASE_PATH, "out", "sov_data", f"env-{elem}-sov.csv"), index=False)

# %%
# prep standardized indiv. envs
elements = ["fire"]

for elem in elements:
    df_elem = pd.read_csv(os.path.join(BASE_PATH, "out", "std_data", f"env-{elem}-pain.csv"), index_col=False)
    df_elem, _ = compute_sova3_subset(df_elem, "Country", "value")
    df_elem.to_csv(os.path.join(BASE_PATH, "out", "sov_data", f"std-env-{elem}-sov.csv"), index=False)

# %%
# PRINT available country names
world = load_world()
for country in set(world["SOVEREIGNT"]):
    print(country)
# Out:
# Cuba
# Republic of Serbia
# Guatemala
# Thailand
# Canada
# Turkmenistan
# Italy
# Georgia
# Guinea
# United Arab Emirates
# Australia
# Morocco
# North Korea
# Eritrea
# Syria
# Mongolia
# Indonesia
# Austria
# Gabon
# Colombia
# Latvia
# Romania
# Northern Cyprus
# Iceland
# Brazil
# Tunisia
# Yemen
# Belize
# New Zealand
# Central African Republic
# Kosovo
# Iran
# Hungary
# Nigeria
# Madagascar
# Oman
# Guyana
# Antarctica
# Algeria
# Portugal
# Kenya
# Haiti
# Honduras
# Republic of the Congo
# Philippines
# United Kingdom
# Gambia
# Bhutan
# Chad
# Croatia
# Vietnam
# Ecuador
# Guinea-Bissau
# Luxembourg
# Bolivia
# Jamaica
# Paraguay
# Denmark
# Costa Rica
# Panama
# Zambia
# Brunei
# Afghanistan
# Rwanda
# Argentina
# Angola
# Burundi
# Albania
# Belarus
# Egypt
# Pakistan
# Western Sahara
# Venezuela
# Azerbaijan
# Qatar
# Lesotho
# Malaysia
# Ghana
# Cambodia
# Uganda
# Germany
# Burkina Faso
# Japan
# Democratic Republic of the Congo
# Montenegro
# Solomon Islands
# Laos
# Greece
# Russia
# Bosnia and Herzegovina
# The Bahamas
# Bulgaria
# China
# Sweden
# Nepal
# Poland
# Israel
# Bangladesh
# Taiwan
# Fiji
# Mauritania
# Ethiopia
# Uruguay
# United Republic of Tanzania
# South Africa
# Switzerland
# Ireland
# Mozambique
# Nicaragua
# Senegal
# Niger
# Zimbabwe
# Netherlands
# Suriname
# Spain
# Benin
# Ukraine
# Somaliland
# Lithuania
# Djibouti
# Ivory Coast
# Togo
# Mexico
# Slovakia
# Sierra Leone
# Myanmar
# Turkey
# Dominican Republic
# Liberia
# Iraq
# Sudan
# Vanuatu
# Moldova
# El Salvador
# Slovenia
# Saudi Arabia
# Uzbekistan
# South Korea
# Sri Lanka
# Cyprus
# Estonia
# Kyrgyzstan
# Chile
# Somalia
# Norway
# United States of America
# France
# Lebanon
# Trinidad and Tobago
# Namibia
# Kuwait
# Czechia
# Mali
# Jordan
# Cameroon
# Peru
# Malawi
# Tajikistan
# North Macedonia
# Papua New Guinea
# Belgium
# East Timor
# India
# Kazakhstan
# Finland
# Botswana
# Equatorial Guinea
# Armenia
# Libya
# eSwatini
# South Sudan
